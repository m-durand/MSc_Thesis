# %%
import pandas as pd

# Visualization
from bokeh.plotting import figure, output_file, show
from ipywidgets import interact
from bokeh.io import push_notebook, show, output_notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e87f54e0-60dc-4e8b-b162-8f52b5dec241">Loading BokehJS ...</span>
#     </div>

# %%
customer_demand = pd.read_csv("../../aux_documents/customer_trend.csv")
fields_supply = pd.read_csv("../../aux_documents/fields_trend.csv")

# %% [markdown]
# ## Supply and Demand trends

# %%
# English

#p_cd = figure(title="Customer Demand - weekly trend with a peak on Independence Day and increased demand on Christmas Holidays", plot_height=450, plot_width=900, x_range = (0,365), y_range=(0,6))
#r_cd = p_cd.line(range(365), customer_demand['Demand'], color="seagreen")
#p_cd.xaxis.axis_label = "Day"
#p_cd.yaxis.axis_label = "Demand"
#show(p_cd, notebook_handle=True)

# Spanish

p_cd = figure(title="Demanda del Cliente - tendencia semanal con un pico el Día de la Independencia y un aumento en las vacaciones de Navidad", plot_height=450, plot_width=900, x_range = (0,365), y_range=(0,6))
r_cd = p_cd.line(range(365), customer_demand['Demand'], color="seagreen")
p_cd.xaxis.axis_label = "Día"
p_cd.yaxis.axis_label = "Demanda"
show(p_cd, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="f1fff2af-9c35-4cb4-b047-88148c79e1b1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
# English

#p_fs = figure(title="Fields Supply - it's only produced in summertime, with a small lift near the end of June and a big lift during August", plot_height=450, plot_width=900, x_range = (0,365), y_range=(0,73))
#r_fs = p_fs.line(range(365), fields_supply['Supply'], color="seagreen")
#p_fs.xaxis.axis_label = "Day"
#p_fs.yaxis.axis_label = "Production"
#show(p_fs, notebook_handle=True)

# Spanish

p_fs = figure(title="Oferta de los Campos - solamente se produce en verano, con un pico pequeño al final de junio y uno grande en agosto", plot_height=450, plot_width=900, x_range = (0,365), y_range=(0,73))
r_fs = p_fs.line(range(365), fields_supply['Supply'], color="seagreen")
p_fs.xaxis.axis_label = "Día"
p_fs.yaxis.axis_label = "Producción"
show(p_fs, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="b1edc819-78c9-40ad-946d-f65d6373d783"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...
